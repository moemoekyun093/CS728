# %%
import numpy as np
import json

# %%
file_path = './updated_vocab_document_dict.json'

# %%
# Open the file in read mode
with open(file_path, 'r') as file:
    data = json.load(file)

# %%
data['0']
# Out:
# [[572,
# ...
